# %% [markdown]
# <p style="text-align: center"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read data from file

# %%
df = pd.read_csv("adult_eda.csv")

# %% [markdown]
# # Try to undersstand what the data looks like? What are types of the features? Are there any missing values? Do I need to eliminate some features?

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors           13.0
# 1   50  Self-emp-not-inc   83311  Bachelors           13.0
# 2   38           Private  215646    HS-grad            9.0
# 3   53           Private  234721       11th            7.0
# 4   28           Private  338409  Bachelors           13.0
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   31759.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.082843   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.576172   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num      802
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Look at the value counts of columns that have object datatype and replace '?' like values with 'Unknown' word.

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
df.describe(include='object')
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      32561     32561               32561           32561        27493
# unique         9        16                   7              15            5
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22696     10501               14976            4140        13193
#
#          race    sex native-country salary
# count   32561  32561          32561  32561
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    27816  21790          29170  24720

# %%
#look at workclass column here
df["workclass"].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df[df.workclass == "?"]
# Out:
#        age workclass  fnlwgt     education  education-num  \
# 27      54         ?  180211  Some-college           10.0
# 61      32         ?  293936       7th-8th            4.0
# 69      25         ?  200681  Some-college           10.0
# 77      67         ?  212759          10th            6.0
# 106     17         ?  304873          10th            6.0
# ...    ...       ...     ...           ...            ...
# 32530   35         ?  320084     Bachelors           13.0
# 32531   30         ?   33811     Bachelors           13.0
# 32539   71         ?  287372     Doctorate            NaN
# 32541   41         ?  202822       HS-grad            9.0
# 32542   72         ?  129912       HS-grad            9.0
#
#               marital-status occupation   relationship                race  \
# 27        Married-civ-spouse          ?        Husband  Asian-Pac-Islander
# 61     Married-spouse-absent          ?  Not-in-family               White
# 69             Never-married          ?            NaN               White
# 77        Married-civ-spouse          ?        Husband               White
# 106            Never-married          ?            NaN               White
# ...                      ...        ...            ...                 ...
# 32530     Married-civ-spouse          ?           Wife               White
# 32531          Never-married          ?  Not-in-family  Asian-Pac-Islander
# 32539     Married-civ-spouse          ?        Husband               White
# 32541              Separated          ?  Not-in-family               Black
# 32542     Married-civ-spouse          ?        Husband               White
#
#           sex  capital-gain  capital-loss  hours-per-week native-country  \
# 27       Male             0             0              60          South
# 61       Male             0             0              40              ?
# 69       Male             0             0              40  United-States
# 77       Male             0             0               2  United-States
# 106    Female         34095             0              32  United-States
# ...       ...           ...           ...             ...            ...
# 32530  Female             0             0              55  United-States
# 32531  Female             0             0              99  United-States
# 32539    Male             0             0              10  United-States
# 32541  Female             0             0              32  United-States
# 32542    Male             0             0              25  United-States
#
#       salary
# 27      >50K
# 61     <=50K
# 69     <=50K
# 77     <=50K
# 106    <=50K
# ...      ...
# 32530   >50K
# 32531  <=50K
# 32539   >50K
# 32541  <=50K
# 32542  <=50K
#
# [1836 rows x 15 columns]

# %%
#replace all '?' in whole df with 'Unknown'
df=df.replace("?", "Unknown")
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors           13.0
# 1       50  Self-emp-not-inc   83311   Bachelors           13.0
# 2       38           Private  215646     HS-grad            9.0
# 3       53           Private  234721        11th            7.0
# 4       28           Private  338409   Bachelors           13.0
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm           12.0
# 32557   40           Private  154374     HS-grad            9.0
# 32558   58           Private  151910     HS-grad            9.0
# 32559   22           Private  201490     HS-grad            9.0
# 32560   52      Self-emp-inc  287927     HS-grad            9.0
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical            NaN  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 15 columns]

# %% [markdown]
# # Do education and education_num columns hold similar information? If so drop the appropriate choice between them.

# %%
df.education
# Out:
# 0         Bachelors
# 1         Bachelors
# 2           HS-grad
# 3              11th
# 4         Bachelors
#             ...
# 32556    Assoc-acdm
# 32557       HS-grad
# 32558       HS-grad
# 32559       HS-grad
# 32560       HS-grad
# Name: education, Length: 32561, dtype: object

# %%
df["education-num"]
# Out:
# 0        13.0
# 1        13.0
# 2         9.0
# 3         7.0
# 4        13.0
#          ...
# 32556    12.0
# 32557     9.0
# 32558     9.0
# 32559     9.0
# 32560     9.0
# Name: education-num, Length: 32561, dtype: float64

# %%
df.groupby('education')['education-num'].value_counts()
# Out:
# education     education-num
# 10th          6.0                916
# 11th          7.0               1146
# 12th          8.0                424
# 1st-4th       2.0                161
# 5th-6th       3.0                330
# 7th-8th       4.0                631
# 9th           5.0                503
# Assoc-acdm    12.0              1044
# Assoc-voc     11.0              1343
# Bachelors     13.0              5247
# Doctorate     16.0               405
# HS-grad       9.0              10215
# Masters       14.0              1687
# Preschool     1.0                 50
# Prof-school   15.0               559
# Some-college  10.0              7098
# Name: education-num, dtype: int64

# %%
df["education-num"].value_counts()
# Out:
# 9.0     10215
# 10.0     7098
# 13.0     5247
# 14.0     1687
# 11.0     1343
# 7.0      1146
# 12.0     1044
# 6.0       916
# 4.0       631
# 15.0      559
# 5.0       503
# 8.0       424
# 16.0      405
# 3.0       330
# 2.0       161
# 1.0        50
# Name: education-num, dtype: int64

# %%
#drop one of them here

# %%
df.drop(columns=["education-num"],inplace=True)

# %%
df
# Out:
#        age         workclass  fnlwgt   education      marital-status  \
# 0       39         State-gov   77516   Bachelors       Never-married
# 1       50  Self-emp-not-inc   83311   Bachelors  Married-civ-spouse
# 2       38           Private  215646     HS-grad            Divorced
# 3       53           Private  234721        11th  Married-civ-spouse
# 4       28           Private  338409   Bachelors  Married-civ-spouse
# ...    ...               ...     ...         ...                 ...
# 32556   27           Private  257302  Assoc-acdm  Married-civ-spouse
# 32557   40           Private  154374     HS-grad  Married-civ-spouse
# 32558   58           Private  151910     HS-grad             Widowed
# 32559   22           Private  201490     HS-grad       Never-married
# 32560   52      Self-emp-inc  287927     HS-grad  Married-civ-spouse
#
#               occupation   relationship   race     sex  capital-gain  \
# 0           Adm-clerical  Not-in-family  White    Male          2174
# 1        Exec-managerial        Husband  White    Male             0
# 2      Handlers-cleaners  Not-in-family  White    Male             0
# 3      Handlers-cleaners        Husband  Black    Male             0
# 4         Prof-specialty           Wife  Black  Female             0
# ...                  ...            ...    ...     ...           ...
# 32556       Tech-support           Wife  White  Female             0
# 32557  Machine-op-inspct        Husband  White    Male             0
# 32558       Adm-clerical      Unmarried  White  Female             0
# 32559       Adm-clerical            NaN  White    Male             0
# 32560    Exec-managerial           Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country salary
# 0                 0              40  United-States  <=50K
# 1                 0              13  United-States  <=50K
# 2                 0              40  United-States  <=50K
# 3                 0              40  United-States  <=50K
# 4                 0              40           Cuba  <=50K
# ...             ...             ...            ...    ...
# 32556             0              38  United-States  <=50K
# 32557             0              40  United-States   >50K
# 32558             0              40  United-States  <=50K
# 32559             0              20  United-States  <=50K
# 32560             0              40  United-States   >50K
#
# [32561 rows x 14 columns]

# %% [markdown]
# ---
# ---

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %% [markdown]
# # Take a look at correlation between variables and also see if there are some outliers in any of the columns.

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education      marital-status  \
# 0   39         State-gov   77516  Bachelors       Never-married
# 1   50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
# 2   38           Private  215646    HS-grad            Divorced
# 3   53           Private  234721       11th  Married-civ-spouse
# 4   28           Private  338409  Bachelors  Married-civ-spouse
#
#           occupation   relationship   race     sex  capital-gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital-loss  hours-per-week native-country salary
# 0             0              40  United-States  <=50K
# 1             0              13  United-States  <=50K
# 2             0              40  United-States  <=50K
# 3             0              40  United-States  <=50K
# 4             0              40           Cuba  <=50K

# %%
df.corr() #sayisal verilerin birbiriyle olan corralasyionu
# Out:
#                      age    fnlwgt  capital-gain  capital-loss  hours-per-week
# age             1.000000 -0.076646      0.077674      0.057775        0.068756
# fnlwgt         -0.076646  1.000000      0.000432     -0.010252       -0.018768
# capital-gain    0.077674  0.000432      1.000000     -0.031615        0.078409
# capital-loss    0.057775 -0.010252     -0.031615      1.000000        0.054256
# hours-per-week  0.068756 -0.018768      0.078409      0.054256        1.000000

# %%
df.salary.value_counts(dropna=False)
# Out:
# <=50K    24720
# >50K      7841
# Name: salary, dtype: int64

# %%
df.salary.map({"<=50K":0, ">50K":1} )
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: salary, Length: 32561, dtype: int64

# %%
df['salary_num']= df.salary.map({"<=50K":0, ">50K":1} )

# %%
df.salary_num.value_counts(dropna=False)
# Out:
# 0    24720
# 1     7841
# Name: salary_num, dtype: int64

# %%
df.corr()
# Out:
#                      age    fnlwgt  capital-gain  capital-loss  \
# age             1.000000 -0.076646      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      0.000432     -0.010252
# capital-gain    0.077674  0.000432      1.000000     -0.031615
# capital-loss    0.057775 -0.010252     -0.031615      1.000000
# hours-per-week  0.068756 -0.018768      0.078409      0.054256
# salary_num      0.234037 -0.009463      0.223329      0.150526
#
#                 hours-per-week  salary_num
# age                   0.068756    0.234037
# fnlwgt               -0.018768   -0.009463
# capital-gain          0.078409    0.223329
# capital-loss          0.054256    0.150526
# hours-per-week        1.000000    0.229689
# salary_num            0.229689    1.000000

# %%
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# age             32561.0      38.581647      13.640433     17.0      28.0
# fnlwgt          32561.0  189778.366512  105549.977697  12285.0  117827.0
# capital-gain    32561.0    1077.648844    7385.292085      0.0       0.0
# capital-loss    32561.0      87.303830     402.960219      0.0       0.0
# hours-per-week  32561.0      40.437456      12.347429      1.0      40.0
# salary_num      32561.0       0.240810       0.427581      0.0       0.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          178356.0  237051.0  1484705.0
# capital-gain         0.0       0.0    99999.0
# capital-loss         0.0       0.0     4356.0
# hours-per-week      40.0      45.0       99.0
# salary_num           0.0       0.0        1.0

# %%
df['age'].plot.box()
# Out:
# <AxesSubplot:>

# %%
#age column
Q1 = df.age.quantile(0.25)
Q3 = df.age.quantile(0.75)
IQR = Q3 - Q1

# %%
IQR
# Out:
# 20.0

# %%
upper_lim = Q3 + (IQR*1.5) 
upper_lim
# Out:
# 78.0

# %%
df[df["age"] >= 78]["age"].value_counts()  #cok yasi gecmis insanlar var demekki burada bi outlier sozkonusu olabilir ucuk rakamlar
# Out:
# 90    43
# 78    23
# 79    22
# 80    22
# 81    20
# 82    12
# 84    10
# 83     6
# 85     3
# 88     3
# 86     1
# 87     1
# Name: age, dtype: int64

# %%
fig ,ax = plt.subplots(2,3,figsize=(20,7))
x = 0
y = 0
for column in df.select_dtypes('number').columns:
    
    df[column].plot(kind = "box", ax = ax[x,y])
    if y < 2:
        y += 1
    else:
        x += 1
        y = 0

# %%
df[(df["hours-per-week"] == 99)].sample(10)
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 19529   38           Private   66326       HS-grad  Married-civ-spouse
# 8796    39           Private   70995     Bachelors  Married-civ-spouse
# 22313   26  Self-emp-not-inc  258306          10th  Married-civ-spouse
# 9831    67           Private   35015       Masters       Never-married
# 21147   39           Private  348521  Some-college  Married-civ-spouse
# 25831   31           Private  147284     Doctorate  Married-civ-spouse
# 10468   44  Self-emp-not-inc  277783       Masters       Never-married
# 26638   55  Self-emp-not-inc  185195     Bachelors  Married-civ-spouse
# 13558   38           Private  191103   Prof-school  Married-civ-spouse
# 19141   59           Private  106748       7th-8th  Married-civ-spouse
#
#              occupation   relationship   race     sex  capital-gain  \
# 19529  Transport-moving        Husband  White    Male             0
# 8796   Transport-moving        Husband  White    Male         15024
# 22313   Farming-fishing        Husband  White    Male             0
# 9831     Prof-specialty  Not-in-family  White    Male             0
# 21147   Farming-fishing        Husband  White    Male             0
# 25831    Prof-specialty        Husband  White    Male             0
# 10468   Farming-fishing            NaN  White    Male             0
# 26638   Exec-managerial        Husband  White    Male             0
# 13558    Prof-specialty        Husband  White    Male             0
# 19141     Other-service           Wife  White  Female             0
#
#        capital-loss  hours-per-week native-country salary  salary_num
# 19529             0              99  United-States  <=50K           0
# 8796              0              99  United-States   >50K           1
# 22313             0              99  United-States  <=50K           0
# 9831              0              99  United-States  <=50K           0
# 21147          2415              99  United-States   >50K           1
# 25831          1977              99  United-States   >50K           1
# 10468             0              99  United-States  <=50K           0
# 26638             0              99  United-States  <=50K           0
# 13558             0              99  United-States   >50K           1
# 19141             0              99  United-States  <=50K           0

# %%
#hours per week column
Q1_hours_per_week = df['hours-per-week'].quantile(0.25)
Q3_hours_per_week = df['hours-per-week'].quantile(0.75)
IQR_hours_per_week = Q3_hours_per_week - Q1_hours_per_week

# %%
IQR_hours_per_week
# Out:
# 5.0

# %%
df['hours-per-week'].describe()
# Out:
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours-per-week, dtype: float64

# %%
upper_lim= Q3_hours_per_week + (IQR_hours_per_week * 1.5)
upper_lim
# Out:
# 52.5

# %%
# find outlier values which extends the upper limit in both age and hours-per-week columns

# %%
df[(df['hours-per-week'] >= upper_lim) & (df['age'] >= upper_lim)]
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 27      54           Unknown  180211  Some-college  Married-civ-spouse
# 118     55           Private  247552  Some-college  Married-civ-spouse
# 329     66           Private  127921       HS-grad       Never-married
# 589     57      Self-emp-inc  103948     Bachelors            Divorced
# 634     58  Self-emp-not-inc   35723       HS-grad  Married-civ-spouse
# ...    ...               ...     ...           ...                 ...
# 32287   54         Local-gov   34832     Doctorate  Married-civ-spouse
# 32391   55           Private  199763       HS-grad           Separated
# 32430   61  Self-emp-not-inc   50483       7th-8th  Married-civ-spouse
# 32469   58      Self-emp-inc  181974     Doctorate       Never-married
# 32548   65  Self-emp-not-inc   99359   Prof-school       Never-married
#
#              occupation   relationship                race     sex  \
# 27              Unknown        Husband  Asian-Pac-Islander    Male
# 118               Sales        Husband               White    Male
# 329    Transport-moving  Not-in-family               White    Male
# 589      Prof-specialty  Not-in-family               White    Male
# 634        Craft-repair        Husband               White    Male
# ...                 ...            ...                 ...     ...
# 32287   Exec-managerial        Husband               White    Male
# 32391   Protective-serv  Not-in-family               White    Male
# 32430   Farming-fishing        Husband               White    Male
# 32469    Prof-specialty  Not-in-family               White  Female
# 32548    Prof-specialty  Not-in-family               White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country salary  \
# 27                0             0              60          South   >50K
# 118               0             0              56  United-States  <=50K
# 329            2050             0              55  United-States  <=50K
# 589               0             0              80  United-States  <=50K
# 634               0             0              60  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 32287             0             0              60  United-States   >50K
# 32391             0             0              81  United-States  <=50K
# 32430             0             0              56  United-States  <=50K
# 32469             0             0              99        Unknown  <=50K
# 32548          1086             0              60  United-States  <=50K
#
#        salary_num
# 27              1
# 118             0
# 329             0
# 589             0
# 634             0
# ...           ...
# 32287           1
# 32391           0
# 32430           0
# 32469           0
# 32548           0
#
# [520 rows x 15 columns]

# %% [markdown]
# # After looking at the outliers you can drop the rows which actually does not make any sense.
# ** Hint: You can check age and hours per week columns. **

# %%
df.age
# Out:
# 0        39
# 1        50
# 2        38
# 3        53
# 4        28
#          ..
# 32556    27
# 32557    40
# 32558    58
# 32559    22
# 32560    52
# Name: age, Length: 32561, dtype: int64

# %%
df['hours-per-week']
# Out:
# 0        40
# 1        13
# 2        40
# 3        40
# 4        40
#          ..
# 32556    38
# 32557    40
# 32558    40
# 32559    20
# 32560    40
# Name: hours-per-week, Length: 32561, dtype: int64

# %%
drop_index= df.index[(df['hours-per-week']>=upper_lim) & (df['age']>=upper_lim)]
drop_index
# Out:
# Int64Index([   27,   118,   329,   589,   634,   729,   741,   763,   794,
#               900,
#             ...
#             31878, 31899, 32090, 32192, 32283, 32287, 32391, 32430, 32469,
#             32548],
#            dtype='int64', length=520)

# %%
df = df.drop(drop_index)

# %%
# check outlier values which extends the upper limit in both age and hours-per-week columns

# %%
df[(df['hours-per-week'] > upper_lim) & (df['age'] > upper_lim)]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary, salary_num]
# Index: []

# %% [markdown]
# # Impute missing values in relationship column with 'Unmarried'. Also replace 'Not-in-family','Other-relative' values in this column with 'Unmarried'?

# %%
df['relationship']
# Out:
# 0        Not-in-family
# 1              Husband
# 2        Not-in-family
# 3              Husband
# 4                 Wife
#              ...
# 32556             Wife
# 32557          Husband
# 32558        Unmarried
# 32559              NaN
# 32560             Wife
# Name: relationship, Length: 32041, dtype: object

# %%
df['relationship'].value_counts()
# Out:
# Husband           12832
# Not-in-family      8194
# Unmarried          3416
# Wife               1559
# Other-relative      975
# Name: relationship, dtype: int64

# %%
df.relationship.value_counts()
# Out:
# Husband           12832
# Not-in-family      8194
# Unmarried          3416
# Wife               1559
# Other-relative      975
# Name: relationship, dtype: int64

# %%
df["relationship"]= df["relationship"].str.replace("Not-in-family","Unmarried").str.replace("Other-relative","Unmarried").fillna("Unmarried")

# %%
df
# Out:
#        age         workclass  fnlwgt   education      marital-status  \
# 0       39         State-gov   77516   Bachelors       Never-married
# 1       50  Self-emp-not-inc   83311   Bachelors  Married-civ-spouse
# 2       38           Private  215646     HS-grad            Divorced
# 3       53           Private  234721        11th  Married-civ-spouse
# 4       28           Private  338409   Bachelors  Married-civ-spouse
# ...    ...               ...     ...         ...                 ...
# 32556   27           Private  257302  Assoc-acdm  Married-civ-spouse
# 32557   40           Private  154374     HS-grad  Married-civ-spouse
# 32558   58           Private  151910     HS-grad             Widowed
# 32559   22           Private  201490     HS-grad       Never-married
# 32560   52      Self-emp-inc  287927     HS-grad  Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# 0           Adm-clerical    Unmarried  White    Male          2174
# 1        Exec-managerial      Husband  White    Male             0
# 2      Handlers-cleaners    Unmarried  White    Male             0
# 3      Handlers-cleaners      Husband  Black    Male             0
# 4         Prof-specialty         Wife  Black  Female             0
# ...                  ...          ...    ...     ...           ...
# 32556       Tech-support         Wife  White  Female             0
# 32557  Machine-op-inspct      Husband  White    Male             0
# 32558       Adm-clerical    Unmarried  White  Female             0
# 32559       Adm-clerical    Unmarried  White    Male             0
# 32560    Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country salary  salary_num
# 0                 0              40  United-States  <=50K           0
# 1                 0              13  United-States  <=50K           0
# 2                 0              40  United-States  <=50K           0
# 3                 0              40  United-States  <=50K           0
# 4                 0              40           Cuba  <=50K           0
# ...             ...             ...            ...    ...         ...
# 32556             0              38  United-States  <=50K           0
# 32557             0              40  United-States   >50K           1
# 32558             0              40  United-States  <=50K           0
# 32559             0              20  United-States  <=50K           0
# 32560             0              40  United-States   >50K           1
#
# [32041 rows x 15 columns]

# %%
df.relationship.value_counts()
# Out:
# Unmarried    17650
# Husband      12832
# Wife          1559
# Name: relationship, dtype: int64

# %% [markdown]
# ---
# # How many of each race are represented in this dataset?
# ---

# %%
race_count = df.race.value_counts()
race_count
# Out:
# White                 27333
# Black                  3102
# Asian-Pac-Islander     1027
# Amer-Indian-Eskimo      309
# Other                   270
# Name: race, dtype: int64

# %%
race_count.sort_values().plot.barh(); #h ekleyince histogram olarak veriyordu yani sekil olarak yan

# %% [markdown]
# ---
# # What is the average age of men/women?
# ---

# %%
average_age_men=df[df.sex == 'Male']['age'].mean()
average_age_men
# Out:
# 39.02393666854038

# %%
average_age_women = df[df.sex == 'Female']['age'].mean()
average_age_women
# Out:
# 36.69250911811466

# %%
round(average_age_men,1)
# Out:
# 39.0

# %%
plt.figure(figsize = (15,7))
df.loc[df["sex"] == "Male", "age"].value_counts().plot.bar();

# %% [markdown]
# ---
# # What is the percentage of people who have a Bachelor's degree?
# ---

# %%
df
# Out:
#        age         workclass  fnlwgt   education      marital-status  \
# 0       39         State-gov   77516   Bachelors       Never-married
# 1       50  Self-emp-not-inc   83311   Bachelors  Married-civ-spouse
# 2       38           Private  215646     HS-grad            Divorced
# 3       53           Private  234721        11th  Married-civ-spouse
# 4       28           Private  338409   Bachelors  Married-civ-spouse
# ...    ...               ...     ...         ...                 ...
# 32556   27           Private  257302  Assoc-acdm  Married-civ-spouse
# 32557   40           Private  154374     HS-grad  Married-civ-spouse
# 32558   58           Private  151910     HS-grad             Widowed
# 32559   22           Private  201490     HS-grad       Never-married
# 32560   52      Self-emp-inc  287927     HS-grad  Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# 0           Adm-clerical    Unmarried  White    Male          2174
# 1        Exec-managerial      Husband  White    Male             0
# 2      Handlers-cleaners    Unmarried  White    Male             0
# 3      Handlers-cleaners      Husband  Black    Male             0
# 4         Prof-specialty         Wife  Black  Female             0
# ...                  ...          ...    ...     ...           ...
# 32556       Tech-support         Wife  White  Female             0
# 32557  Machine-op-inspct      Husband  White    Male             0
# 32558       Adm-clerical    Unmarried  White  Female             0
# 32559       Adm-clerical    Unmarried  White    Male             0
# 32560    Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country salary  salary_num
# 0                 0              40  United-States  <=50K           0
# 1                 0              13  United-States  <=50K           0
# 2                 0              40  United-States  <=50K           0
# 3                 0              40  United-States  <=50K           0
# 4                 0              40           Cuba  <=50K           0
# ...             ...             ...            ...    ...         ...
# 32556             0              38  United-States  <=50K           0
# 32557             0              40  United-States   >50K           1
# 32558             0              40  United-States  <=50K           0
# 32559             0              20  United-States  <=50K           0
# 32560             0              40  United-States   >50K           1
#
# [32041 rows x 15 columns]

# %%
df.groupby('education')['education'].count()
# Out:
# education
# 10th              914
# 11th             1169
# 12th              431
# 1st-4th           165
# 5th-6th           327
# 7th-8th           621
# 9th               504
# Assoc-acdm       1058
# Assoc-voc        1370
# Bachelors        5268
# Doctorate         386
# HS-grad         10351
# Masters          1660
# Preschool          50
# Prof-school       557
# Some-college     7210
# Name: education, dtype: int64

# %%
df.education.value_counts()
# Out:
# HS-grad         10351
# Some-college     7210
# Bachelors        5268
# Masters          1660
# Assoc-voc        1370
# 11th             1169
# Assoc-acdm       1058
# 10th              914
# 7th-8th           621
# Prof-school       557
# 9th               504
# 12th              431
# Doctorate         386
# 5th-6th           327
# 1st-4th           165
# Preschool          50
# Name: education, dtype: int64

# %%
upper = df["education"][df.education == "Bachelors"].count()
upper
lower = df["education"].count()
lower

percentage_bachelors = (upper / lower) * 100
percentage_bachelors
# Out:
# 16.44143441215942

# %%
df["education"].value_counts(normalize=True   # direk yuzdeliklerini veriyor her biriin
# Out:
# HS-grad         0.323055
# Some-college    0.225024
# Bachelors       0.164414
# Masters         0.051809
# Assoc-voc       0.042758
# 11th            0.036485
# Assoc-acdm      0.033020
# 10th            0.028526
# 7th-8th         0.019381
# Prof-school     0.017384
# 9th             0.015730
# 12th            0.013452
# Doctorate       0.012047
# 5th-6th         0.010206
# 1st-4th         0.005150
# Preschool       0.001561
# Name: education, dtype: float64

# %%
percentage_bachelors = df["education"].value_counts(normalize=True).loc["Bachelors"]*100
round(percentage_bachelors,1)
# Out:
# 16.4

# %%
print(f'The percentage of people who have a Bachelors degree: %{round(percentage_bachelors,1)}')
# Out:
# The percentage of people who have a Bachelors degree: %16.4

# %% [markdown]
# ---
# # What percentage of people with advanced education (`Bachelors`, `Masters`, or `Doctorate`) make more than 50K?
# ---

# %%
df.education.isin(['Bachelors', 'Masters', 'Doctorate'])
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: education, Length: 32041, dtype: bool

# %%
(df.education== 'Bachelors') | (df.education=='Masters') | (df.education=='Doctorate')
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: education, Length: 32041, dtype: bool

# %%
df.salary == ">50K"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557     True
# 32558    False
# 32559    False
# 32560     True
# Name: salary, Length: 32041, dtype: bool

# %%
high_edu_high_sal=len(df[((df.education== 'Bachelors') | (df.education=='Masters') | (df.education=='Doctorate')) & (df.salary == ">50K")])

# %%
total = df.shape[0]

# %%
perc_high_edu = high_edu_high_sal / total

# %%
   perc_high_edu
# Out:
# 0.105177741019319

# %%
   perc_high_edu *100
# Out:
# 10.5177741019319

# %% [markdown]
# ---
# # What percentage of people without advanced education make more than 50K?
# ---

# %%
df[(~df.education.isin(['Bachelors', 'Masters', 'Doctorate']))& (df.salary =='>50K')]
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 7       52  Self-emp-not-inc  209642       HS-grad  Married-civ-spouse
# 10      37           Private  280464  Some-college  Married-civ-spouse
# 14      40           Private  121772     Assoc-voc  Married-civ-spouse
# 38      31           Private   84154  Some-college  Married-civ-spouse
# 52      47           Private   51835   Prof-school  Married-civ-spouse
# ...    ...               ...     ...           ...                 ...
# 32518   57         Local-gov  110417       HS-grad  Married-civ-spouse
# 32519   46           Private  364548  Some-college  Married-civ-spouse
# 32545   39         Local-gov  111499    Assoc-acdm  Married-civ-spouse
# 32557   40           Private  154374       HS-grad  Married-civ-spouse
# 32560   52      Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation relationship                race     sex  \
# 7        Exec-managerial      Husband               White    Male
# 10       Exec-managerial      Husband               Black    Male
# 14          Craft-repair      Husband  Asian-Pac-Islander    Male
# 38                 Sales      Husband               White    Male
# 52        Prof-specialty         Wife               White  Female
# ...                  ...          ...                 ...     ...
# 32518       Craft-repair      Husband               White    Male
# 32519    Exec-managerial      Husband               White    Male
# 32545       Adm-clerical         Wife               White  Female
# 32557  Machine-op-inspct      Husband               White    Male
# 32560    Exec-managerial         Wife               White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary  \
# 7                 0             0              45  United-States   >50K
# 10                0             0              80  United-States   >50K
# 14                0             0              40        Unknown   >50K
# 38                0             0              38        Unknown   >50K
# 52                0          1902              60       Honduras   >50K
# ...             ...           ...             ...            ...    ...
# 32518         99999             0              40  United-States   >50K
# 32519             0             0              48  United-States   >50K
# 32545             0             0              20  United-States   >50K
# 32557             0             0              40  United-States   >50K
# 32560         15024             0              40  United-States   >50K
#
#        salary_num
# 7               1
# 10              1
# 14              1
# 38              1
# 52              1
# ...           ...
# 32518           1
# 32519           1
# 32545           1
# 32557           1
# 32560           1
#
# [4222 rows x 15 columns]

# %%
low_edu_high_sal = df[(~df.education.isin(['Bachelors', 'Masters', 'Doctorate']))& (df.salary =='>50K')]

# %%
total = df.shape[0]

# %%
total
# Out:
# 32041

# %%
perc_low_edu = low_edu_high_sal/total

# %%
print(f"Percentage of people without advanced education make more than 50K : {round(perc_low_edu * 100 ,2)}")

# %%
if perc_high_edu > perc_low_edu :
    print("More education more money!")
else:
    print("Education has no clear effet on salary. You should investigate some other features also.")

# %% [markdown]
# ---
# # What percentage of the people who work the minimum number of hours per week have a salary of >50K?
# ---

# %%
df['hours-per-week']== df['hours-per-week'].min()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: hours-per-week, Length: 32041, dtype: bool

# %%
df.salary=='>50K'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557     True
# 32558    False
# 32559    False
# 32560     True
# Name: salary, Length: 32041, dtype: bool

# %%
(df['hours-per-week']== df['hours-per-week'].min()) & (df.salary=='>50K')

# %%
lazy_riches = (df['hours-per-week']== df['hours-per-week'].min()) & (df.salary=='>50K')
lazy_riches
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32041, dtype: bool

# %%
df[lazy_riches]
# Out:
#        age  workclass  fnlwgt  education      marital-status      occupation  \
# 189     58  State-gov  109567  Doctorate  Married-civ-spouse  Prof-specialty
# 20072   65    Unknown   76043    HS-grad  Married-civ-spouse         Unknown
#
#       relationship   race   sex  capital-gain  capital-loss  hours-per-week  \
# 189        Husband  White  Male             0             0               1
# 20072      Husband  White  Male             0             0               1
#
#       native-country salary  salary_num
# 189    United-States   >50K           1
# 20072  United-States   >50K           1

# %%
num_lazy_riches = df[lazy_riches].shape[0]
num_lazy_riches
# Out:
# 2

# %%
num_min_workers = len(df[df['hours-per-week']== df['hours-per-week'].min()])
num_min_workers
# Out:
# 20

# %%
print (f"Percentage of the people who work the minimum number of hours per week have a salary of >50K : % {round(num_lazy_riches/num_min_workers*100)}")
# Out:
# Percentage of the people who work the minimum number of hours per week have a salary of >50K : % 10

# %% [markdown]
#  ---
#  # What country has the highest percentage of people that earn >50K?
#  ---

# %%
country_salary_df = df.groupby('native-country')[['salary']].count()
country_salary_df
# Out:
#                             salary
# native-country
# Cambodia                        19
# Canada                         116
# China                           74
# Columbia                        59
# Cuba                            95
# Dominican-Republic              69
# Ecuador                         28
# El-Salvador                    106
# England                         90
# France                          29
# Germany                        134
# Greece                          27
# Guatemala                       64
# Haiti                           42
# Holand-Netherlands               1
# Honduras                        13
# Hong                            20
# Hungary                         12
# India                          100
# Iran                            43
# Ireland                         23
# Italy                           72
# Jamaica                         81
# Japan                           62
# Laos                            18
# Mexico                         642
# Nicaragua                       34
# Outlying-US(Guam-USVI-etc)      14
# Peru                            31
# Philippines                    195
# Poland                          60
# Portugal                        37
# Puerto-Rico                    114
# Scotland                        12
# South                           77
# Taiwan                          51
# Thailand                        18
# Trinadad&Tobago                 19
# United-States                28686
# Unknown                        571
# Vietnam                         67
# Yugoslavia                      16

# %%
country_salary_df_riches = df[df.salary==">50K"].groupby('native-country')[['salary']].count()

# %%
country_salary_df_riches
# Out:
#                     salary
# native-country
# Cambodia                 7
# Canada                  37
# China                   20
# Columbia                 2
# Cuba                    25
# Dominican-Republic       2
# Ecuador                  4
# El-Salvador              9
# England                 30
# France                  12
# Germany                 42
# Greece                   7
# Guatemala                3
# Haiti                    3
# Honduras                 1
# Hong                     6
# Hungary                  2
# India                   40
# Iran                    18
# Ireland                  5
# Italy                   24
# Jamaica                 10
# Japan                   24
# Laos                     2
# Mexico                  33
# Nicaragua                2
# Peru                     2
# Philippines             60
# Poland                  12
# Portugal                 4
# Puerto-Rico             12
# Scotland                 3
# South                   14
# Taiwan                  20
# Thailand                 3
# Trinadad&Tobago          2
# United-States         6938
# Unknown                141
# Vietnam                  5
# Yugoslavia               6

# %%
rich_per_country=df[(country_salary_df_riches / country_salary_df).sort_values(by='salary',ascending=False)]

# %%
rich_per_country
# Out:
#        age workclass  fnlwgt education marital-status occupation relationship  \
# 0      NaN       NaN     NaN       NaN            NaN        NaN          NaN
# 1      NaN       NaN     NaN       NaN            NaN        NaN          NaN
# 2      NaN       NaN     NaN       NaN            NaN        NaN          NaN
# 3      NaN       NaN     NaN       NaN            NaN        NaN          NaN
# 4      NaN       NaN     NaN       NaN            NaN        NaN          NaN
# ...    ...       ...     ...       ...            ...        ...          ...
# 32556  NaN       NaN     NaN       NaN            NaN        NaN          NaN
# 32557  NaN       NaN     NaN       NaN            NaN        NaN          NaN
# 32558  NaN       NaN     NaN       NaN            NaN        NaN          NaN
# 32559  NaN       NaN     NaN       NaN            NaN        NaN          NaN
# 32560  NaN       NaN     NaN       NaN            NaN        NaN          NaN
#
#       race  sex  capital-gain  capital-loss  hours-per-week native-country  \
# 0      NaN  NaN           NaN           NaN             NaN            NaN
# 1      NaN  NaN           NaN           NaN             NaN            NaN
# 2      NaN  NaN           NaN           NaN             NaN            NaN
# 3      NaN  NaN           NaN           NaN             NaN            NaN
# 4      NaN  NaN           NaN           NaN             NaN            NaN
# ...    ...  ...           ...           ...             ...            ...
# 32556  NaN  NaN           NaN           NaN             NaN            NaN
# 32557  NaN  NaN           NaN           NaN             NaN            NaN
# 32558  NaN  NaN           NaN           NaN             NaN            NaN
# 32559  NaN  NaN           NaN           NaN             NaN            NaN
# 32560  NaN  NaN           NaN           NaN             NaN            NaN
#
#       salary  salary_num
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN
# ...      ...         ...
# 32556    NaN         NaN
# 32557    NaN         NaN
# 32558    NaN         NaN
# 32559    NaN         NaN
# 32560    NaN         NaN
#
# [32041 rows x 15 columns]

# %%
plt.figure(figsize=(14,7))
df.loc[df["salary"] == ">50K", "native-country"].value_counts().plot(kind="bar");

# %%
plt.figure(figsize=(12,6))
df.loc[((df["native-country"] == "Iran")), "salary"].value_counts().plot.bar();

# %% [markdown]
# ---
# # Identify the most popular occupation for those who earn >50K in India.
# ---

# %%
top_IN_occupation = (df['native-country']== 'India') & (df.salary == '>50K')

# %%
top_IN_occupation
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32041, dtype: bool

# %%
df[top_IN_occupation]
# Out:
#        age         workclass  fnlwgt    education         marital-status  \
# 11      30         State-gov  141297    Bachelors     Married-civ-spouse
# 968     48           Private  164966    Bachelors     Married-civ-spouse
# 1327    52           Private  168381      HS-grad                Widowed
# 7258    42         State-gov  102343  Prof-school     Married-civ-spouse
# 7285    54         State-gov   93449      Masters     Married-civ-spouse
# 8124    36           Private  172104  Prof-school          Never-married
# 9939    43       Federal-gov  325706  Prof-school     Married-civ-spouse
# 10590   35           Private   98283  Prof-school          Never-married
# 10661   59           Private  122283  Prof-school     Married-civ-spouse
# 10736   30           Private  243190  Prof-school     Married-civ-spouse
# 11260   54           Private  225599      Masters     Married-civ-spouse
# 11384   34           Private   98283  Prof-school          Never-married
# 13422   53           Private  366957    Bachelors     Married-civ-spouse
# 13551   40           Private  220977    Doctorate     Married-civ-spouse
# 13862   45           Private  209912    Bachelors     Married-civ-spouse
# 16017   41           Private  207578   Assoc-acdm     Married-civ-spouse
# 16778   43           Private  242968      Masters     Married-civ-spouse
# 16923   41           Private  143003    Assoc-voc     Married-civ-spouse
# 17259   57      Self-emp-inc  123053  Prof-school     Married-civ-spouse
# 17834   29  Self-emp-not-inc  341672      HS-grad  Married-spouse-absent
# 20417   42      Self-emp-inc   23510      Masters               Divorced
# 20465   39           Private  198654  Prof-school     Married-civ-spouse
# 21128   30           Private  122889      Masters     Married-civ-spouse
# 23474   55         State-gov  120781    Doctorate     Married-civ-spouse
# 24154   46           Private  229737    Bachelors     Married-civ-spouse
# 25739   35      Self-emp-inc   79586      Masters     Married-civ-spouse
# 26305   27           Private  207352    Bachelors     Married-civ-spouse
# 26356   34           Private   99872      Masters     Married-civ-spouse
# 27670   61           Private   80896      Masters     Married-civ-spouse
# 28264   51  Self-emp-not-inc  120781  Prof-school     Married-civ-spouse
# 28433   42           Private  198341      Masters     Married-civ-spouse
# 28452   53           Private   70387      Masters     Married-civ-spouse
# 28557   34           Private  165737      Masters     Married-civ-spouse
# 28651   45  Self-emp-not-inc  216402  Prof-school     Married-civ-spouse
# 28798   30  Self-emp-not-inc  116666      Masters               Divorced
# 30111   41       Federal-gov  219155  Prof-school     Married-civ-spouse
# 30152   48           Private  119471    Doctorate     Married-civ-spouse
# 30833   25           Private  110978   Assoc-acdm     Married-civ-spouse
# 31327   38         State-gov  125499    Bachelors     Married-civ-spouse
# 31357   23           Private  143003      Masters     Married-civ-spouse
#
#              occupation relationship                race     sex  \
# 11       Prof-specialty      Husband  Asian-Pac-Islander    Male
# 968     Exec-managerial      Husband  Asian-Pac-Islander    Male
# 1327      Other-service    Unmarried  Asian-Pac-Islander  Female
# 7258     Prof-specialty      Husband  Asian-Pac-Islander    Male
# 7285     Prof-specialty      Husband  Asian-Pac-Islander    Male
# 8124     Prof-specialty    Unmarried               Other    Male
# 9939     Prof-specialty      Husband  Asian-Pac-Islander    Male
# 10590    Prof-specialty    Unmarried  Asian-Pac-Islander    Male
# 10661    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 10736    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 11260    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 11384      Tech-support    Unmarried  Asian-Pac-Islander    Male
# 13422   Exec-managerial      Husband  Asian-Pac-Islander    Male
# 13551   Exec-managerial      Husband  Asian-Pac-Islander    Male
# 13862   Exec-managerial      Husband  Asian-Pac-Islander    Male
# 16017   Exec-managerial      Husband               Black    Male
# 16778   Exec-managerial      Husband  Asian-Pac-Islander    Male
# 16923     Other-service      Husband  Asian-Pac-Islander    Male
# 17259    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 17834  Transport-moving    Unmarried  Asian-Pac-Islander    Male
# 20417   Exec-managerial    Unmarried  Asian-Pac-Islander    Male
# 20465    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 21128    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 23474    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 24154             Sales      Husband               White    Male
# 25739    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 26305      Tech-support      Husband  Asian-Pac-Islander    Male
# 26356   Exec-managerial      Husband  Asian-Pac-Islander    Male
# 27670    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 28264    Prof-specialty      Husband               Other    Male
# 28433    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 28452    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 28557    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 28651    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 28798    Prof-specialty    Unmarried  Asian-Pac-Islander    Male
# 30111    Prof-specialty      Husband               White    Male
# 30152    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 30833      Adm-clerical         Wife  Asian-Pac-Islander  Female
# 31327    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 31357    Prof-specialty      Husband  Asian-Pac-Islander    Male
#
#        capital-gain  capital-loss  hours-per-week native-country salary  \
# 11                0             0              40          India   >50K
# 968               0             0              40          India   >50K
# 1327              0             0              40          India   >50K
# 7258              0             0              72          India   >50K
# 7285              0             0              40          India   >50K
# 8124              0             0              40          India   >50K
# 9939              0             0              50          India   >50K
# 10590             0             0              40          India   >50K
# 10661         99999             0              40          India   >50K
# 10736             0             0              20          India   >50K
# 11260          7298             0              40          India   >50K
# 11384             0          1564              40          India   >50K
# 13422         99999             0              50          India   >50K
# 13551          3103             0              40          India   >50K
# 13862             0             0              40          India   >50K
# 16017             0             0              50          India   >50K
# 16778             0             0              40          India   >50K
# 16923          7298             0              60          India   >50K
# 17259         15024             0              50          India   >50K
# 17834             0          1564              50          India   >50K
# 20417             0          2201              60          India   >50K
# 20465             0          2415              67          India   >50K
# 21128             0             0              50          India   >50K
# 23474             0             0              40          India   >50K
# 24154             0             0              50          India   >50K
# 25739             0             0              40          India   >50K
# 26305             0             0              40          India   >50K
# 26356          3103             0              40          India   >50K
# 27670             0             0              45          India   >50K
# 28264         99999             0              70          India   >50K
# 28433             0          1902              55          India   >50K
# 28452          4386             0              40          India   >50K
# 28557             0             0              43          India   >50K
# 28651             0             0              50          India   >50K
# 28798             0             0              50          India   >50K
# 30111             0             0              50          India   >50K
# 30152             0             0              40          India   >50K
# 30833             0             0              37          India   >50K
# 31327          7688             0              60          India   >50K
# 31357             0          1887              50          India   >50K
#
#        salary_num
# 11              1
# 968             1
# 1327            1
# 7258            1
# 7285            1
# 8124            1
# 9939            1
# 10590           1
# 10661           1
# 10736           1
# 11260           1
# 11384           1
# 13422           1
# 13551           1
# 13862           1
# 16017           1
# 16778           1
# 16923           1
# 17259           1
# 17834           1
# 20417           1
# 20465           1
# 21128           1
# 23474           1
# 24154           1
# 25739           1
# 26305           1
# 26356           1
# 27670           1
# 28264           1
# 28433           1
# 28452           1
# 28557           1
# 28651           1
# 28798           1
# 30111           1
# 30152           1
# 30833           1
# 31327           1
# 31357           1

# %%
df[top_IN_occupation]['occupation'].value_counts()
# Out:
# Prof-specialty      25
# Exec-managerial      8
# Other-service        2
# Tech-support         2
# Sales                1
# Transport-moving     1
# Adm-clerical         1
# Name: occupation, dtype: int64

# %%
df[top_IN_occupation]['occupation'].mode()[0]
# Out:
# 'Prof-specialty'
